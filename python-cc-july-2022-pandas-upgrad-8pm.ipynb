# %%
print('I like Pandas')
# Out:
# I like Pandas

# %%
# ModuleNotFoundError: No module named 'numpy'
# !pip install numpy

# ModuleNotFoundError: No module named 'pandas'
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (1.21.6)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.21.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
lst = [10,20,30]
print(lst, type(lst))

import numpy as np

arr = np.array(lst)
print(arr, type(arr))

import pandas as pd
# Out:
# [10, 20, 30] <class 'list'>
# [10 20 30] <class 'numpy.ndarray'>

# %%
lst = [10,20,30]
print(lst, type(lst))

arr = np.array(lst)
print(arr, type(arr))

# Series
srs = pd.Series(data=lst)
print(srs)
print(type(srs))
# Out:
# [10, 20, 30] <class 'list'>
# [10 20 30] <class 'numpy.ndarray'>
# 0    10
# 1    20
# 2    30
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
lst = [10,20,30.0]
print(lst, type(lst))

arr = np.array(lst)
print(arr, type(arr))

# Series
srs = pd.Series(data=lst)
print(srs)
print(type(srs))
# Out:
# [10, 20, 30.0] <class 'list'>
# [10. 20. 30.] <class 'numpy.ndarray'>
# 0    10.0
# 1    20.0
# 2    30.0
# dtype: float64
# <class 'pandas.core.series.Series'>

# %%
lst = [10,'20',30.0]
print(lst, type(lst))

arr = np.array(lst)
print(arr, type(arr))

# Series
srs = pd.Series(data=lst)
print(srs)
print(type(srs))
# Out:
# [10, '20', 30.0] <class 'list'>
# ['10' '20' '30.0'] <class 'numpy.ndarray'>
# 0      10
# 1      20
# 2    30.0
# dtype: object
# <class 'pandas.core.series.Series'>

# %%
'a b c'.split()
# Out:
# ['a', 'b', 'c']

# %%
lst = [10,20,30]
print(lst, type(lst))

arr = np.array(lst)
print(arr, type(arr))

# Series
srs = pd.Series(data=lst, index=['a', 'b', 'c'])
print(srs)
print(type(srs))
print(srs.index)
# Out:
# [10, 20, 30] <class 'list'>
# [10 20 30] <class 'numpy.ndarray'>
# a    10
# b    20
# c    30
# dtype: int64
# <class 'pandas.core.series.Series'>
# Index(['a', 'b', 'c'], dtype='object')

# %%
dct = {'a':10, 'b':20,'c':30}
srs = pd.Series(data=dct)
print(srs)
print(type(srs))
print(srs.index)
print(srs.dtype)
# Out:
# a    10
# b    20
# c    30
# dtype: int64
# <class 'pandas.core.series.Series'>
# Index(['a', 'b', 'c'], dtype='object')
# int64

# %%
srs = pd.Series(data=[10,20,30], index=['a', 'b', 'c'])
print(srs)
print(srs.index)
# getting values
print(srs['b'])
print(srs.iloc[1])
print(srs.iloc[-2])
# Out:
# a    10
# b    20
# c    30
# dtype: int64
# Index(['a', 'b', 'c'], dtype='object')
# 20
# 20
# 20

# %%
srs = pd.Series(data=[10,20,30], index=[1,2,3])
print(srs)
print(srs.index)
# getting values
print(srs[1])
print(srs.iloc[-2])
print(srs.values)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64
# Int64Index([1, 2, 3], dtype='int64')
# 10
# 20
# [10 20 30]

# %%
# maths
srs = pd.Series(data=[10,20,30], index=['a', 'b', 'c'])
print(srs)

print('>> +')
print(srs+srs)
print(srs+2)
print('>> -')
print(srs-srs)
print(srs-2)
print('>> *')
print(srs*srs)
print(srs*2)
print('>> /')
print(srs/srs)
print(srs/2)
# Out:
# a    10
# b    20
# c    30
# dtype: int64
# >> +
# a    20
# b    40
# c    60
# dtype: int64
# a    12
# b    22
# c    32
# dtype: int64
# >> -
# a    0
# b    0
# c    0
# dtype: int64
# a     8
# b    18
# c    28
# dtype: int64
# >> *
# a    100
# b    400
# c    900
# dtype: int64
# a    20
# b    40
# c    60
# dtype: int64
# >> /
# a    1.0
# b    1.0
# c    1.0
# dtype: float64
# a     5.0
# b    10.0
# c    15.0
# dtype: float64

# %%
# maths
srs1 = pd.Series(data=[10,20,30], index=['a', 'b', 'c'])
print(srs1)
srs2 = pd.Series(data=[10,20,30], index=['b', 'c', 'd'])
print(srs2)

print('>> +')
print(srs1+srs2)
print('>> /')
print(srs1/srs2)
print('>> *')
print(srs1*srs2)
print('>> -')
print(srs1-srs2)
# Out:
# a    10
# b    20
# c    30
# dtype: int64
# b    10
# c    20
# d    30
# dtype: int64
# >> +
# a     NaN
# b    30.0
# c    50.0
# d     NaN
# dtype: float64
# >> /
# a    NaN
# b    2.0
# c    1.5
# d    NaN
# dtype: float64
# >> *
# a      NaN
# b    200.0
# c    600.0
# d      NaN
# dtype: float64
# >> -
# a     NaN
# b    10.0
# c    10.0
# d     NaN
# dtype: float64

# %%
arr = np.random.rand(5,4)
print(arr)
# Out:
# [[0.82799292 0.62220468 0.86663687 0.08024382]
#  [0.64801804 0.6046969  0.53043442 0.20232648]
#  [0.90008299 0.55069699 0.99523247 0.71943081]
#  [0.3921118  0.44338488 0.92948149 0.50730004]
#  [0.8798632  0.84740744 0.04447053 0.20865544]]

# %%
# DataFrame
df = pd.DataFrame(data = arr, index='a b c d e'.split(), columns='C1 C2 C3 C4'.split())
print(type(df))
print(df.index)
print(df.columns)
print(df.dtypes)
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')
# Index(['C1', 'C2', 'C3', 'C4'], dtype='object')
# C1    float64
# C2    float64
# C3    float64
# C4    float64
# dtype: object
#          C1        C2        C3        C4
# a  0.827993  0.622205  0.866637  0.080244
# b  0.648018  0.604697  0.530434  0.202326
# c  0.900083  0.550697  0.995232  0.719431
# d  0.392112  0.443385  0.929481  0.507300
# e  0.879863  0.847407  0.044471  0.208655

# %%
# DataFrame
df = pd.DataFrame(data = arr, index='a b c d e'.split())
print(type(df))
print(df.index)
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')
#           0         1         2         3
# a  0.827993  0.622205  0.866637  0.080244
# b  0.648018  0.604697  0.530434  0.202326
# c  0.900083  0.550697  0.995232  0.719431
# d  0.392112  0.443385  0.929481  0.507300
# e  0.879863  0.847407  0.044471  0.208655

# %%
# DataFrame
df = pd.DataFrame(data = arr)
print(type(df))
# print(df)
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#           0         1         2         3
# 0  0.827993  0.622205  0.866637  0.080244
# 1  0.648018  0.604697  0.530434  0.202326
# 2  0.900083  0.550697  0.995232  0.719431
# 3  0.392112  0.443385  0.929481  0.507300
# 4  0.879863  0.847407  0.044471  0.208655
#           0         1         2         3
# 0  0.827993  0.622205  0.866637  0.080244
# 1  0.648018  0.604697  0.530434  0.202326
# 2  0.900083  0.550697  0.995232  0.719431
# 3  0.392112  0.443385  0.929481  0.507300
# 4  0.879863  0.847407  0.044471  0.208655

# %%
# DataFrame
df = pd.DataFrame(data = arr, index='a b c d e'.split(), columns='C1 C2 C3 C4'.split())
# col
col = df['C3']
print(col)
print(type(col))
col = df.C3
print(col)
print(type(col))
df
# Out:
# a    0.866637
# b    0.530434
# c    0.995232
# d    0.929481
# e    0.044471
# Name: C3, dtype: float64
# <class 'pandas.core.series.Series'>
# a    0.866637
# b    0.530434
# c    0.995232
# d    0.929481
# e    0.044471
# Name: C3, dtype: float64
# <class 'pandas.core.series.Series'>
#          C1        C2        C3        C4
# a  0.827993  0.622205  0.866637  0.080244
# b  0.648018  0.604697  0.530434  0.202326
# c  0.900083  0.550697  0.995232  0.719431
# d  0.392112  0.443385  0.929481  0.507300
# e  0.879863  0.847407  0.044471  0.208655

# %%
# DataFrame
df = pd.DataFrame(data = arr, index='a b c d e'.split(), columns='C1 C2 C3 C4'.split())
df[['C3','C1']]
# Out:
#          C3        C1
# a  0.866637  0.827993
# b  0.530434  0.648018
# c  0.995232  0.900083
# d  0.929481  0.392112
# e  0.044471  0.879863

# %%
df = pd.DataFrame(data = arr, index='a b c d e'.split(), columns='C1 C2 C3 C4'.split())
print(df.C3-df.C1)
df["new col"] = df.C3-df.C1
df
# Out:
# a    0.038644
# b   -0.117584
# c    0.095149
# d    0.537370
# e   -0.835393
# dtype: float64
#          C1        C2        C3        C4   new col
# a  0.827993  0.622205  0.866637  0.080244  0.038644
# b  0.648018  0.604697  0.530434  0.202326 -0.117584
# c  0.900083  0.550697  0.995232  0.719431  0.095149
# d  0.392112  0.443385  0.929481  0.507300  0.537370
# e  0.879863  0.847407  0.044471  0.208655 -0.835393

# %%
ddf = df.drop('new col', axis=1)
ddf
# Out:
#          C1        C2        C3        C4
# a  0.827993  0.622205  0.866637  0.080244
# b  0.648018  0.604697  0.530434  0.202326
# c  0.900083  0.550697  0.995232  0.719431
# d  0.392112  0.443385  0.929481  0.507300
# e  0.879863  0.847407  0.044471  0.208655

# %%
df.drop('new col', axis=1, inplace =True)
df
# Out:
#          C1        C2        C3        C4
# a  0.827993  0.622205  0.866637  0.080244
# b  0.648018  0.604697  0.530434  0.202326
# c  0.900083  0.550697  0.995232  0.719431
# d  0.392112  0.443385  0.929481  0.507300
# e  0.879863  0.847407  0.044471  0.208655

# %%
df.drop('b', axis=0, inplace =True)
df
# Out:
#          C1        C2        C3        C4
# a  0.827993  0.622205  0.866637  0.080244
# c  0.900083  0.550697  0.995232  0.719431
# d  0.392112  0.443385  0.929481  0.507300
# e  0.879863  0.847407  0.044471  0.208655

# %%
df = pd.DataFrame(data = arr, index='a b c d e'.split(), columns='C1 C2 C3 C4'.split())
df
# Out:
#          C1        C2        C3        C4
# a  0.827993  0.622205  0.866637  0.080244
# b  0.648018  0.604697  0.530434  0.202326
# c  0.900083  0.550697  0.995232  0.719431
# d  0.392112  0.443385  0.929481  0.507300
# e  0.879863  0.847407  0.044471  0.208655

# %%
# single value eg 0.530434
## col > row
print(df['C3']['b'])
print(df.C3['b'])
print(df['C3'].iloc[1])
print(df.C3.iloc[1])
## row > col
print(df.loc['b']['C3'])
print(df.iloc[1]['C3'])
print(df.loc['b'].iloc[2])
print(df.iloc[1].iloc[2])
print(df.loc['b','C3'])
print(df.iloc[1,2])
# Out:
# 0.530434416762594
# 0.530434416762594
# 0.530434416762594
# 0.530434416762594
# 0.530434416762594
# 0.530434416762594
# 0.530434416762594
# 0.530434416762594
# 0.530434416762594
# 0.530434416762594

# %%
# row
print(df.loc['b'])
print(df.iloc[1])
# Out:
# C1    0.648018
# C2    0.604697
# C3    0.530434
# C4    0.202326
# Name: b, dtype: float64
# C1    0.648018
# C2    0.604697
# C3    0.530434
# C4    0.202326
# Name: b, dtype: float64

# %%
# col
print(df['C3'])
print(df.C3)
# Out:
# a    0.866637
# b    0.530434
# c    0.995232
# d    0.929481
# e    0.044471
# Name: C3, dtype: float64
# a    0.866637
# b    0.530434
# c    0.995232
# d    0.929481
# e    0.044471
# Name: C3, dtype: float64

# %%
df = pd.DataFrame(data = arr, index='a b c d e'.split(), columns='C1 C2 C3 C4'.split())
df
# Out:
#          C1        C2        C3        C4
# a  0.827993  0.622205  0.866637  0.080244
# b  0.648018  0.604697  0.530434  0.202326
# c  0.900083  0.550697  0.995232  0.719431
# d  0.392112  0.443385  0.929481  0.507300
# e  0.879863  0.847407  0.044471  0.208655

# %%
df.set_index('C3')
# Out:
#                 C1        C2        C4
# C3
# 0.866637  0.827993  0.622205  0.080244
# 0.530434  0.648018  0.604697  0.202326
# 0.995232  0.900083  0.550697  0.719431
# 0.929481  0.392112  0.443385  0.507300
# 0.044471  0.879863  0.847407  0.208655

# %%
df = pd.DataFrame(data = arr, index='a b c d e'.split(), columns='C1 C2 C3 C4'.split())
df
# Out:
#          C1        C2        C3        C4
# a  0.827993  0.622205  0.866637  0.080244
# b  0.648018  0.604697  0.530434  0.202326
# c  0.900083  0.550697  0.995232  0.719431
# d  0.392112  0.443385  0.929481  0.507300
# e  0.879863  0.847407  0.044471  0.208655

# %%
df.reset_index(drop=True)
# Out:
#          C1        C2        C3        C4
# 0  0.827993  0.622205  0.866637  0.080244
# 1  0.648018  0.604697  0.530434  0.202326
# 2  0.900083  0.550697  0.995232  0.719431
# 3  0.392112  0.443385  0.929481  0.507300
# 4  0.879863  0.847407  0.044471  0.208655

# %%
arr = np.array([1,3,5])
print(arr)
print(arr>4)
print(arr[arr>4])
# Out:
# [1 3 5]
# [False False  True]
# [5]

# %%
df = pd.DataFrame(data = np.random.rand(5,4), index='a b c d e'.split(), columns='C1 C2 C3 C4'.split())
df
# Out:
#          C1        C2        C3        C4
# a  0.242239  0.675643  0.559959  0.050062
# b  0.632920  0.544965  0.071555  0.102802
# c  0.573501  0.080664  0.698448  0.766437
# d  0.231983  0.328327  0.984654  0.716508
# e  0.418460  0.210355  0.577606  0.386843

# %%
df[df.C4>0.5]
# Out:
#          C1        C2        C3        C4
# c  0.573501  0.080664  0.698448  0.766437
# d  0.231983  0.328327  0.984654  0.716508

# %%
df[df>0.5]
# Out:
#          C1        C2        C3        C4
# a       NaN  0.675643  0.559959       NaN
# b  0.632920  0.544965       NaN       NaN
# c  0.573501       NaN  0.698448  0.766437
# d       NaN       NaN  0.984654  0.716508
# e       NaN       NaN  0.577606       NaN

# %%
# conditionals
df>0.5
# Out:
#       C1     C2     C3     C4
# a  False   True   True  False
# b   True   True  False  False
# c   True  False   True   True
# d  False  False   True   True
# e  False  False   True  False

# %%
df = pd.DataFrame(data = np.random.rand(5,4), index='a b c d e'.split(), columns='C1 C2 C3 C4'.split())
new_df = df[df>0.5]
new_df
# Out:
#          C1        C2        C3        C4
# a       NaN       NaN       NaN       NaN
# b  0.567746  0.986964  0.759458  0.732848
# c       NaN  0.544485  0.912091       NaN
# d  0.655155  0.511016       NaN       NaN
# e       NaN  0.945690       NaN       NaN

# %%
(0.912091+0.759458)/2
# Out:
# 0.8357745

# %%
new_df['C3']=new_df.C3.fillna(value = new_df.C3.mean())
new_df
# Out:
#          C1        C2        C3        C4
# a       NaN       NaN  0.835774       NaN
# b  0.567746  0.986964  0.759458  0.732848
# c       NaN  0.544485  0.912091       NaN
# d  0.655155  0.511016  0.835774       NaN
# e       NaN  0.945690  0.835774       NaN

# %%
new_df.fillna(value = 0)
# Out:
#          C1        C2        C3        C4
# a  0.000000  0.000000  0.000000  0.000000
# b  0.567746  0.986964  0.759458  0.732848
# c  0.000000  0.544485  0.912091  0.000000
# d  0.655155  0.511016  0.000000  0.000000
# e  0.000000  0.945690  0.000000  0.000000

# %%
new_df.dropna(thresh=2)# at least thresh number of non NAN values should be present
# Out:
#          C1        C2        C3        C4
# b  0.567746  0.986964  0.759458  0.732848
# c       NaN  0.544485  0.912091       NaN
# d  0.655155  0.511016       NaN       NaN

# %%
new_df.dropna()
# Out:
#          C1        C2        C3        C4
# b  0.567746  0.986964  0.759458  0.732848

# %%
data = {
    'Country':['in','in','cn','us','cn'],
    'Flag':['A','B','A','B','A'],
    'Score':[1,2,3,2,1]
}
df = pd.DataFrame(data)
df
# Out:
#   Country Flag  Score
# 0      in    A      1
# 1      in    B      2
# 2      cn    A      3
# 3      us    B      2
# 4      cn    A      1

# %%
# drop duplicates
df.drop_duplicates(['Country', 'Flag'], )
# Out:
#   Country Flag  Score
# 0      in    A      1
# 1      in    B      2
# 2      cn    A      3
# 3      us    B      2

# %%
# sort the values
df.sort_values(['Score', 'Country'], ascending=[False, True])
# Out:
#   Country Flag  Score
# 2      cn    A      3
# 1      in    B      2
# 3      us    B      2
# 4      cn    A      1
# 0      in    A      1

# %%
# value count
print(df.Country.value_counts())
# Out:
# in    2
# cn    2
# us    1
# Name: Country, dtype: int64

# %%
# nunique
print(df.Country.nunique())
# Out:
# 3

# %%
# unique
print(df.Country.unique())
# Out:
# ['in' 'cn' 'us']

# %%
data = {
    'Country':['in','in','cn','us','cn'],
    'Flag':['A','B','A','B','A'],
    'Score':[1,2,3,2,1]
}
df = pd.DataFrame(data)
df
# Out:
#   Country Flag  Score
# 0      in    A      1
# 1      in    B      2
# 2      cn    A      3
# 3      us    B      2
# 4      cn    A      1

# %%
def my_sq_func(x):
    return x*x
df['Squared_Score']=df.Score.apply(my_sq_func)
df
# Out:
#   Country Flag  Score  Squared_Score
# 0      in    A      1              1
# 1      in    B      2              4
# 2      cn    A      3              9
# 3      us    B      2              4
# 4      cn    A      1              1

# %%
def my_sum_func(a,b):
    return a+b
df['Squared_Sum_Score']=df.apply(lambda df:my_sum_func(a=df.Score,b=df.Squared_Score), axis=1)
df
# Out:
#   Country Flag  Score  Squared_Score  Squared_Sum_Score
# 0      in    A      1              1                  2
# 1      in    B      2              4                  6
# 2      cn    A      3              9                 12
# 3      us    B      2              4                  6
# 4      cn    A      1              1                  2

# %%
df.groupby('Country').sum()
# Out:
#          Score  Squared_Score  Squared_Sum_Score
# Country
# cn           4             10                 14
# in           3              5                  8
# us           2              4                  6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            5 non-null      object
#  1   Flag               5 non-null      object
#  2   Score              5 non-null      int64
#  3   Squared_Score      5 non-null      int64
#  4   Squared_Sum_Score  5 non-null      int64
# dtypes: int64(3), object(2)
# memory usage: 328.0+ bytes

# %%
df.groupby('Country').count()
# Out:
#          Flag  Score  Squared_Score  Squared_Sum_Score
# Country
# cn          2      2              2                  2
# in          2      2              2                  2
# us          1      1              1                  1

# %%
df.describe()
# Out:
#          Score  Squared_Score  Squared_Sum_Score
# count  5.00000       5.000000            5.00000
# mean   1.80000       3.800000            5.60000
# std    0.83666       3.271085            4.09878
# min    1.00000       1.000000            2.00000
# 25%    1.00000       1.000000            2.00000
# 50%    2.00000       4.000000            6.00000
# 75%    2.00000       4.000000            6.00000
# max    3.00000       9.000000           12.00000

# %%
# SBI
# adhaar, name, bal

# govt 
# adhaar, name, criminal

# >>>
# adhaar, name, bal, criminal

# %%
sbi_df = pd.DataFrame({
'aadhaarNo':["000003", "000005", "000001", "000006", "000002"],
'Name':     ["Tony",   "Thor",   "Natasha", "Fury", "Groot"],
'Balance':  [999999,    100,      200,        300,     0]
})
govt_df = pd.DataFrame({
'identificationNo':["000001", "000002", "000003", "000004", "000005", "000006"],
'Name':            ["Natasha", "Groot",  "Tony",   "Tony",   "Thor",   "Fury"],
'criminal':        [True,       True,      True,    False,   False,    False]
})

# %%
sbi_df
# Out:
#   aadhaarNo     Name  Balance
# 0    000003     Tony   999999
# 1    000005     Thor      100
# 2    000001  Natasha      200
# 3    000006     Fury      300
# 4    000002    Groot        0

# %%
govt_df
# Out:
#   identificationNo     Name  criminal
# 0           000001  Natasha      True
# 1           000002    Groot      True
# 2           000003     Tony      True
# 3           000004     Tony     False
# 4           000005     Thor     False
# 5           000006     Fury     False

# %%
pd.merge(left = sbi_df, right = govt_df, how='inner', left_on = ['aadhaarNo', 'Name'], right_on = ['identificationNo', 'Name'])
# Out:
#   aadhaarNo     Name  Balance identificationNo  criminal
# 0    000003     Tony   999999           000003      True
# 1    000005     Thor      100           000005     False
# 2    000001  Natasha      200           000001      True
# 3    000006     Fury      300           000006     False
# 4    000002    Groot        0           000002      True

# %%
pd.merge(left = sbi_df, right = govt_df, how='inner', left_on = 'aadhaarNo', right_on = 'identificationNo', suffixes = ("_sbi", "_govt"))
# Out:
#   aadhaarNo Name_sbi  Balance identificationNo Name_govt  criminal
# 0    000003     Tony   999999           000003      Tony      True
# 1    000005     Thor      100           000005      Thor     False
# 2    000001  Natasha      200           000001   Natasha      True
# 3    000006     Fury      300           000006      Fury     False
# 4    000002    Groot        0           000002     Groot      True

# %%
pd.merge(left = sbi_df, right = govt_df, how='inner', on='Name')
# Out:
#   aadhaarNo     Name  Balance identificationNo  criminal
# 0    000003     Tony   999999           000003      True
# 1    000003     Tony   999999           000004     False
# 2    000005     Thor      100           000005     False
# 3    000001  Natasha      200           000001      True
# 4    000006     Fury      300           000006     False
# 5    000002    Groot        0           000002      True
